# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\python38.zip', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\DLLs', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\lib', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv', '', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\lib\\site-packages', 'c:\\users\\nehcr\\documents\\projects\\nba_database', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\lib\\site-packages\\win32', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\lib\\site-packages\\win32\\lib', 'c:\\Users\\nehcr\\Documents\\Projects\\nba_database\\venv\\lib\\site-packages\\Pythonwin']

# %%
from BasketballReferenceLinks import BasketBallReferenceLinks
from datetime import datetime, timedelta
import calendar
from requests import get
from bs4 import BeautifulSoup
import unicodedata
import unidecode
import requests
from bs4 import Comment
import pandas as pd
import lxml

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../../data/player_per_game_stats/player_per_game_stats_2024.csv')
df
# Out:
#       Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  \
# 0      1  Precious Achiuwa  PF-C  24  TOT  74  18  21.9  3.2   6.3  .501  0.4
# 1      1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  .459  0.5
# 2      1  Precious Achiuwa    PF  24  NYK  49  18  24.2  3.2   6.1  .525  0.3
# 3      2       Bam Adebayo     C  26  MIA  71  71  34.0  7.5  14.3  .521  0.2
# 4      3      Ochai Agbaji    SG  23  TOT  78  28  21.0  2.3   5.6  .411  0.8
# ..   ...               ...   ...  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 758  568    Thaddeus Young    PF  35  PHO  10   0   8.9  1.1   2.1  .524  0.0
# 759  569        Trae Young    PG  25  ATL  54  54  36.0  8.0  18.7  .430  3.2
# 760  570    Omer Yurtseven     C  25  UTA  48  12  11.4  2.1   3.8  .538  0.1
# 761  571       Cody Zeller     C  31  NOP  43   0   7.4  0.6   1.4  .419  0.0
# 762  572       Ivica Zubac     C  26  LAC  68  68  26.4  5.0   7.6  .649  0.0
#
#      3PA   3P%   2P   2PA   2P%  eFG%   FT  FTA   FT%  ORB  DRB   TRB   AST  \
# 0    1.3  .268  2.8   5.0  .562  .529  0.9  1.5  .616  2.6  4.0   6.6   1.3
# 1    1.9  .277  2.6   4.9  .528  .497  1.0  1.7  .571  2.0  3.4   5.4   1.8
# 2    1.0  .260  2.9   5.1  .578  .547  0.9  1.4  .643  2.9  4.3   7.2   1.1
# 3    0.6  .357  7.3  13.7  .528  .529  4.1  5.5  .755  2.2  8.1  10.4   3.9
# 4    2.7  .294  1.5   2.8  .523  .483  0.5  0.7  .661  0.9  1.8   2.8   1.1
# ..   ...   ...  ...   ...   ...   ...  ...  ...   ...  ...  ...   ...   ...
# 758  0.1  .000  1.1   2.0  .550  .524  0.1  0.3  .333  1.7  1.1   2.8   0.7
# 759  8.7  .373  4.8  10.0  .479  .516  6.4  7.5  .855  0.4  2.3   2.8  10.8
# 760  0.5  .208  2.0   3.3  .588  .552  0.4  0.6  .679  1.5  2.8   4.3   0.6
# 761  0.1  .333  0.6   1.4  .424  .427  0.5  0.9  .605  1.1  1.5   2.6   0.9
# 762  0.0   NaN  5.0   7.6  .649  .649  1.8  2.4  .723  2.9  6.3   9.2   1.4
#
#      STL  BLK  TOV   PF   PTS
# 0    0.6  0.9  1.1  1.9   7.6
# 1    0.6  0.5  1.2  1.6   7.7
# 2    0.6  1.1  1.1  2.1   7.6
# 3    1.1  0.9  2.3  2.2  19.3
# 4    0.6  0.6  0.8  1.5   5.8
# ..   ...  ...  ...  ...   ...
# 758  0.5  0.2  0.4  1.1   2.3
# 759  1.3  0.2  4.4  2.0  25.7
# 760  0.2  0.4  0.8  1.1   4.6
# 761  0.2  0.1  0.4  1.0   1.8
# 762  0.3  1.2  1.2  2.6  11.7
#
# [763 rows x 30 columns]
